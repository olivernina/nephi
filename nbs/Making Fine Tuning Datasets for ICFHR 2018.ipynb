# %% [markdown]
# ## The following code makes lmdb databases for the specific data in the ICFHR 2018 competition. Part of the competition is to find out how many pages of specific documents are truly necessary to successfully fine tune a general handwriting recognition model to a particular document type. They have provided 1, 4 and 16 pages of each document type to test fine-tuning performance on the test set. I believe a good validation split for us is to fine-tune on the 8 pages not in the 4 page set, and then validate on the 4 pages. The provided 1 and 4 page sets are strict subsets of the fine-tune lists with more numbers of pages (4 and 16, respectively)

# %%
import os
import sys
from glob import glob
import shutil
import subprocess

# %%
lmdb_database_base = "/deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc"
spec_tr_lists_dir = "/deep_data/datasets/ICFHR_Data/specific_data_train_list"
spec_lists_files = glob(os.path.join(spec_tr_lists_dir, "*"))
dirs = [os.path.basename(f).partition(".lst")[0] for f in spec_lists_files]

# %% [markdown]
# ### Make directories for lmdb databases

# %%
for num in set([d.partition("_train_")[0] for d in dirs]):
    dirs.append(num + "_train_8")
for d in dirs:
    os.makedirs(os.path.join(lmdb_database_base, d))

# %% [markdown]
# ### Loop through all of the lists and make the 8 page fine-tuning training lists for validating our fine-tuning approach

# %%
spec_val_lists_dir = "/deep_data/datasets/ICFHR_Data/specific_data_val_list"
for num in set([d.partition("_train_")[0] for d in dirs]):
    #list_1 = os.path.join(spec_tr_lists_dir, num + "_train_1.lst")
    list_4 = os.path.join(spec_tr_lists_dir, num + "_train_4.lst")
    list_16 = os.path.join(spec_tr_lists_dir, num + "_train_16.lst")
    with open(list_16, "r") as t_16, open(list_4, "r") as t_4:
        imgs_16 = set(t_16.read().split())
        imgs_4 = set(t_4.read().split())
        imgs_8 = imgs_16 - imgs_4
        
        list_8 = os.path.join(spec_val_lists_dir, num + "_train_8.lst")
        
        with open(list_8, "w") as val_8:
            for img in imgs_8:
                val_8.write(img + "\n")

# %% [markdown]
# ### Verify that the files are correct (they are correct)

# %%
for num in set([d.partition("_train_")[0] for d in dirs]):
    list_8 = os.path.join(spec_val_lists_dir, num + "_train_8.lst")
    list_4 = os.path.join(spec_tr_lists_dir, num + "_train_4.lst")
    list_16 = os.path.join(spec_tr_lists_dir, num + "_train_16.lst")
    with open(list_16, "r") as t_16, open(list_4, "r") as t_4, open(list_8, "r") as t_8:
        imgs_16 = set(t_16.read().split())
        imgs_4 = set(t_4.read().split())
        imgs_8 = set(t_8.read().split())
        test_8 = imgs_16 - imgs_4
        print ("Testing number:" + num)
        print(str(imgs_8 == test_8))
# Out:
# Testing number:30882
# True
# Testing number:35013
# True
# Testing number:30893
# True
# Testing number:35015
# True
# Testing number:30866
# True

# %% [markdown]
# ### Make all the python calls to create lmdb databases for all lists

# %%
lmdb_database_base = "/deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc"
spec_tr_lists_dir = "/deep_data/datasets/ICFHR_Data/specific_data_train_list"
train_data = "/deep_data/datasets/ICFHR_Data/specific_data"

#python create_dataset.py ~/datasets/read_ICFHR/specific_data ~/russell/nephi/data/lmdb_ICFHR/specific_data --icfhr /file to include

for num in set([d.partition("_train_")[0] for d in dirs]):
    for s in ["1", "4", "8", "16"]:
        script=''
        if s=="8":
            script = ' '.join(["python create_dataset.py", train_data, os.path.join(lmdb_database_base, num + "_train_" + s), "--icfhr", os.path.join(spec_val_lists_dir, num + "_train_8.lst")])
        else:
            script = ' '.join(["python create_dataset.py", train_data, os.path.join(lmdb_database_base, num + "_train_" + s), "--icfhr", os.path.join(spec_tr_lists_dir , num + "_train_" + s + ".lst")])
        print(script)
# Out:
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30882_train_1 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/30882_train_1.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30882_train_4 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/30882_train_4.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30882_train_8 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_val_list/30882_train_8.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30882_train_16 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/30882_train_16.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/35013_train_1 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/35013_train_1.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/35013_train_4 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/35013_train_4.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/35013_train_8 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_val_list/35013_train_8.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/35013_train_16 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/35013_train_16.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30893_train_1 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/30893_train_1.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30893_train_4 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/30893_train_4.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30893_train_8 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_val_list/30893_train_8.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30893_train_16 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/30893_train_16.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/35015_train_1 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/35015_train_1.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/35015_train_4 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/35015_train_4.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/35015_train_8 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_val_list/35015_train_8.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/35015_train_16 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/35015_train_16.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30866_train_1 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/30866_train_1.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30866_train_4 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/30866_train_4.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30866_train_8 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_val_list/30866_train_8.lst
# python create_dataset.py /deep_data/datasets/ICFHR_Data/specific_data /deep_data/nephi/data/lmdb_ICFHR/specific_data_each_doc/30866_train_16 --icfhr /deep_data/datasets/ICFHR_Data/specific_data_train_list/30866_train_16.lst

# %% [markdown]
# ## Now make all the crnn_main calls to fine tune the results on different specific data before using it on test data

# %%
#python crnn_main.py --trainroot data/lmdb_ICFHR_bin/general_data 
#--valroot data/lmdb_ICFHR_bin/specific_data --dataset ICFHR 
#--cuda --lr 0.0001 --displayInterval 120 --valEpoch 1 --saveEpoch 1 
#--workers 3 --niter 200 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch
#--keep_ratio --imgH 60 --imgW 240 --batchSize 2 > log_files/expr_ICFHR_7May_removing_binarization_eachepoch.txt

# Here was the best model training on general data and validating on specific data:
#0.4007 First model I want to try
#experiments/expr_ICFHR_27Apr_binarization_distortion_randomaffine_testside/netCRNN_27_5963.pth
#0.3937 one model I could try
#experiments/expr_ICFHR_27Apr_binarization_distortion_randomaffine_testside/netCRNN_45_5963.

# for round 2 0.3907 was the error.
# experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth
#Make sure to do the training augmentation, same one.


lmdb_database_base = "/deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/"

pretrained_path = "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth"

# Let's make the script
#python crnn_main.py --trainroot this is the specific data 1, 4, 16 /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/general_data 
#--valroot this will be the corresponding train_8 for validation /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/specific_data --dataset ICFHR --cuda --lr 0.0001 
#--displayInterval 120 --valEpoch 1 --saveEpoch 1 --workers 10 --niter 15 --experiment this should be a name unique to the train setexperiments/expr_ICFHR_17Apr_binarization_augmentation 
#--keep_ratio --imgH 60 --imgW 240 --batchSize 6 --binarize > name unique to the train set log_files/log_ICFHR_17Apr_binarization_augmentation.txt

for num in set([d.partition("_train_")[0] for d in dirs]):
    for s in ["1", "4", "16"]:
        script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num + "_train_" + s), 
                           "--valroot", os.path.join(lmdb_database_base, num + "_train_" + "8"), 
                               "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2", 
                           "--experiment", "/home/remi10001/deep_data/experiments/expr_" + "ICFHR_7May_finetuning_nobinarize_" + num + "_train_" + s, 
                           "--crnn",  pretrained_path, ">",
                           "log_files/log_ICFHR_7May_finetuning_nobinarize_" + num + "_train_" + s + ".txt"])
        print(script)
        print
# Out:
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35013_train_1 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_35013_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35013_train_4 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_35013_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35013_train_16 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_35013_train_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30882_train_1 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_30882_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30882_train_4 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_30882_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30882_train_16 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_30882_train_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30893_train_1 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_30893_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30893_train_4 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_30893_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30893_train_16 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_30893_train_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_1 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_30866_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_4 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_30866_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_16 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_30866_train_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35015_train_1 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_35015_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35015_train_4 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_35015_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35015_train_16 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth > log_files/log_ICFHR_7May_finetuning_nobinarize_35015_train_16.txt

# %%
# Here was the best model training on general data and validating on specific data:
#0.4007 First model I want to try
#experiments/expr_ICFHR_27Apr_binarization_distortion_randomaffine_testside/netCRNN_27_5963.pth
#0.3937 one model I could try
#experiments/expr_ICFHR_27Apr_binarization_distortion_randomaffine_testside/netCRNN_45_5963.

# for round 2 0.3907 was the error.
# experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth
#Make sure to do the training augmentation, same one.


lmdb_database_base = "/deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/"



# Let's make the script
#python crnn_main.py --trainroot this is the specific data 1, 4, 16 /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/general_data 
#--valroot this will be the corresponding train_8 for validation /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/specific_data --dataset ICFHR --cuda --lr 0.0001 
#--displayInterval 120 --valEpoch 1 --saveEpoch 1 --workers 10 --niter 15 --experiment this should be a name unique to the train setexperiments/expr_ICFHR_17Apr_binarization_augmentation 
#--keep_ratio --imgH 60 --imgW 240 --batchSize 6 --binarize > name unique to the train set log_files/log_ICFHR_17Apr_binarization_augmentation.txt

for num in set([d.partition("_train_")[0] for d in dirs]):
    for s in ["1", "4", "16"]:
        script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num + "_train_" + s), "--valroot", os.path.join(lmdb_database_base, num + "_train_" + "8"), 
                               "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize", 
                           "--experiment", "/home/remi10001/deep_data/experiments/expr_" + "ICFHR_3May_finetuning_fullaugment_correctsize_" + num + "_train_" + s, 
                           "--crnn",  "experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth", ">",
                           "log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_" + num + "_train_" + s + ".txt"])
        print(script)
        print
# Out:
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_1 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_4 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35013_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_16 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_1 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_4 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30882_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_16 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_1 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_4 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30893_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_16 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_1 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_4 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/30866_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_16 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_1 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_1 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_4 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_4 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_16 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/specific_data_each_doc/35015_train_8 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 40 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --experiment /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_16 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth > log_files/log_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_16.txt

# %% [markdown]
# ## Now make all the predictions on the test set

# %% [markdown]
# ### Predictions for the 4th submission, without binarization

# %%
! mkdir ../test_results/7May_fourth_submission_nobinarization


#experiments/expr_ICFHR_17Apr_binarization_augmentation/netCRNN_6_1988.pth
lmdb_database_base = "/deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/"

/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_1/netCRNN_8_15.pth

tuned_models = ["/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35013_train_1/netCRNN_18_19.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35013_train_4/netCRNN_23_78.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35013_train_16/netCRNN_24_321.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30882_train_1/netCRNN_7_11.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30882_train_4/netCRNN_12_42.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30882_train_16/netCRNN_15_164.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30893_train_1/netCRNN_3_10.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30893_train_4/netCRNN_16_44.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30893_train_16/netCRNN_39_192.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_1/netCRNN_8_15.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_4/netCRNN_13_58.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_16/netCRNN_25_235.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35015_train_1/netCRNN_25_34.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35015_train_4/netCRNN_15_132.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35015_train_16/netCRNN_21_529.pth"]

i = 0
for num in set([d.partition("_train_")[0] for d in dirs]):
    for s in ["0", "1", "4", "16"]:
        script = ''
        if s == "0":
            script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num), 
                           "--valroot", os.path.join(lmdb_database_base, num), 
                           "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15",
                           "--keep_ratio --imgH 60 --imgW 240 --batchSize 2", # "--test_aug --n_aug 30" ,
                           #"--experiment", "experiments/expr_" + "ICFHR_18Apr_finetuning_allnet_" + num + "_train_" + s, 
                           "--crnn",  "/home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth", 
                           "--test_icfhr --test_file", os.path.join("test_results/7May_fourth_submission_nobinarization", num + "_" + s + ".txt"), ">",
                           "log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_" + num + "_" + s + ".txt"])
        else:
            script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num), 
                           "--valroot", os.path.join(lmdb_database_base, num), 
                           "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15",
                           "--keep_ratio --imgH 60 --imgW 240 --batchSize 2", "--test_aug --n_aug 37" ,
                           #"--experiment", "experiments/expr_" + "ICFHR_18Apr_finetuning_allnet_" + num + "_train_" + s, 
                           "--crnn",  tuned_models[i], 
                           "--test_icfhr --test_file", os.path.join("test_results/7May_fourth_submission_nobinarization", num + "_" + s + ".txt"), ">",
                           "log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_" + num + "_" + s + ".txt"])
            i = i + 1
        print(script)
        print
# Out:
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/35013_0.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_35013_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35013_train_1/netCRNN_18_19.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/35013_1.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_35013_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35013_train_4/netCRNN_23_78.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/35013_4.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_35013_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35013_train_16/netCRNN_24_321.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/35013_16.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_35013_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30882_0.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30882_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30882_train_1/netCRNN_7_11.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30882_1.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30882_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30882_train_4/netCRNN_12_42.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30882_4.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30882_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30882_train_16/netCRNN_15_164.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30882_16.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30882_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30893_0.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30893_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30893_train_1/netCRNN_3_10.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30893_1.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30893_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30893_train_4/netCRNN_16_44.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30893_4.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30893_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30893_train_16/netCRNN_39_192.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30893_16.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30893_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30866_0.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30866_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_1/netCRNN_8_15.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30866_1.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30866_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_4/netCRNN_13_58.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30866_4.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30866_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_30866_train_16/netCRNN_25_235.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/30866_16.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_30866_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_removing_binarization_eachepoch/netCRNN_27_5963.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/35015_0.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_35015_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35015_train_1/netCRNN_25_34.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/35015_1.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_35015_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35015_train_4/netCRNN_15_132.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/35015_4.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_35015_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --test_aug --n_aug 37 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_7May_finetuning_nobinarize_35015_train_16/netCRNN_21_529.pth --test_icfhr --test_file test_results/7May_fourth_submission_nobinarization/35015_16.txt > log_files/test_logs/log_ICFHR_7May_fourth_submission_nobinarization_35015_16.txt

# %%
! mkdir ../test_results/3May_third_submission_fullaugment_correct_size

#experiments/expr_ICFHR_17Apr_binarization_augmentation/netCRNN_6_1988.pth
lmdb_database_base = "/deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/"

tuned_models = [ "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_1/netCRNN_31_19.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_4/netCRNN_20_78.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_16/netCRNN_16_321.pth",
    
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_1/netCRNN_28_11.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_4/netCRNN_32_42.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_16/netCRNN_32_164.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_1/netCRNN_3_10.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_4/netCRNN_1_44.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_16/netCRNN_4_192.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_1/netCRNN_39_15.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_4/netCRNN_13_58.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_16/netCRNN_36_235.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_1/netCRNN_34_34.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_4/netCRNN_34_132.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_16/netCRNN_35_529.pth"]
# Let's make the script
#python crnn_main.py --trainroot this is the specific data 1, 4, 16 /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/general_data 
#--valroot this will be the corresponding train_8 for validation /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/specific_data --dataset ICFHR --cuda --lr 0.0001 
#--displayInterval 120 --valEpoch 1 --saveEpoch 1 --workers 10 --niter 15 --experiment this should be a name unique to the train setexperiments/expr_ICFHR_17Apr_binarization_augmentation 
#--keep_ratio --imgH 60 --imgW 240 --batchSize 6 --binarize > name unique to the train set log_files/log_ICFHR_17Apr_binarization_augmentation.txt

#python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR/general_data 
#--valroot /deep_data/nephi/data/lmdb_ICFHR/test_data/30865_testtrack 
#--crnn /deep_data/nephi/experiments/expr_ICFHR_27Mar_alph_werr_fixed_extended/netCRNN_20_5963.pth 
#--cuda --lr 0.00005 --displayInterval 120 --valEpoch 5 --saveEpoch 10 --workers 10 --niter 200
#--experiment experiments/expr_ICFHR_24Mar_testset_test --keep_ratio --imgH 80 --imgW 240 --batchSize 32
#--test_icfhr --test_file 30865_0_unicodeformatted.txt > log_ICFHR_27Mar_russell_testset_test.txt
i = 0
for num in set([d.partition("_train_")[0] for d in dirs]):
    for s in ["0", "1", "4", "16"]:
        script = ''
        if s == "0":
            script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num), 
                           "--valroot", os.path.join(lmdb_database_base, num), 
                           "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15",
                           "--keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize", "--test_aug --n_aug 30" ,
                           #"--experiment", "experiments/expr_" + "ICFHR_18Apr_finetuning_allnet_" + num + "_train_" + s, 
                           "--crnn",  "experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth", 
                           "--test_icfhr --test_file", os.path.join("test_results/3May_third_submission_fullaugment_correct_size", num + "_" + s + ".txt"), ">",
                           "log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_" + num + "_" + s + ".txt"])
        else:
            script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num), 
                           "--valroot", os.path.join(lmdb_database_base, num), 
                           "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15",
                           "--keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize", "--test_aug --n_aug 30" ,
                           #"--experiment", "experiments/expr_" + "ICFHR_18Apr_finetuning_allnet_" + num + "_train_" + s, 
                           "--crnn",  tuned_models[i], 
                           "--test_icfhr --test_file", os.path.join("test_results/3May_third_submission_fullaugment_correct_size", num + "_" + s + ".txt"), ">",
                           "log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_" + num + "_" + s + ".txt"])
            i = i + 1
        print(script)
        print
# Out:
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/35013_0.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_35013_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_1/netCRNN_31_19.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/35013_1.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_35013_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_4/netCRNN_20_78.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/35013_4.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_35013_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35013 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35013_train_16/netCRNN_16_321.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/35013_16.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_35013_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30882_0.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30882_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_1/netCRNN_28_11.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30882_1.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30882_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_4/netCRNN_32_42.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30882_4.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30882_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30882 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30882_train_16/netCRNN_32_164.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30882_16.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30882_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30893_0.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30893_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_1/netCRNN_3_10.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30893_1.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30893_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_4/netCRNN_1_44.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30893_4.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30893_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30893 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30893_train_16/netCRNN_4_192.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30893_16.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30893_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30866_0.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30866_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_1/netCRNN_39_15.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30866_1.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30866_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_4/netCRNN_13_58.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30866_4.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30866_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/30866 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_30866_train_16/netCRNN_36_235.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/30866_16.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_30866_16.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn experiments/expr_ICFHR_2May_binarization_distortion_randomaffine_testside_tune_height/netCRNN_3_5963.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/35015_0.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_35015_0.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_1/netCRNN_34_34.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/35015_1.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_35015_1.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_4/netCRNN_34_132.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/35015_4.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_35015_4.txt
#
# python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --valroot /deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/35015 --dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15 --keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize --test_aug --n_aug 30 --crnn /home/remi10001/deep_data/experiments/expr_ICFHR_3May_finetuning_fullaugment_correctsize_35015_train_16/netCRNN_35_529.pth --test_icfhr --test_file test_results/3May_third_submission_fullaugment_correct_size/35015_16.txt > log_files/test_logs/log_ICFHR_3May_third_submission_fullaugment_correct_size_35015_16.txt

# %% [markdown]
# ### These were the first test set predictions

# %%
#experiments/expr_ICFHR_17Apr_binarization_augmentation/netCRNN_6_1988.pth
lmdb_database_base = "/deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/"

tuned_models = ["/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35013_train_1/netCRNN_28_19.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35013_train_4/netCRNN_38_78.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35013_train_16/netCRNN_27_321.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30882_train_1/netCRNN_38_11.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30882_train_4/netCRNN_28_42.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30882_train_16/netCRNN_32_164.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30893_train_1/netCRNN_4_10.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30893_train_4/netCRNN_32_44.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30893_train_16/netCRNN_36_192.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30866_train_1/netCRNN_24_15.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30866_train_4/netCRNN_37_58.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30866_train_16/netCRNN_38_235.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35015_train_1/netCRNN_30_34.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35015_train_4/netCRNN_38_132.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35015_train_16/netCRNN_28_529.pth",
                
                
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_35013_train_1/netCRNN_5_7.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_35013_train_4/netCRNN_6_26.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_35013_train_16/netCRNN_8_107.pth",
            
                                        
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_30882_train_1/netCRNN_6_4.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_30882_train_4/netCRNN_6_14.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_30882_train_16/netCRNN_7_55.pth",
                

                
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_30893_train_1/netCRNN_7_4.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_30893_train_4/netCRNN_12_15.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_30893_train_16/netCRNN_14_64.pth",
                

                "experiments/expr_ICFHR_18Apr_finetuning_allnet_30866_train_1/netCRNN_14_5.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_30866_train_4/netCRNN_13_20.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_30866_train_16/netCRNN_12_79.pth",
                
                
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_35015_train_1/netCRNN_14_12.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_35015_train_4/netCRNN_7_44.pth",
                "experiments/expr_ICFHR_18Apr_finetuning_allnet_35015_train_16/netCRNN_8_177.pth"]

# Let's make the script
#python crnn_main.py --trainroot this is the specific data 1, 4, 16 /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/general_data 
#--valroot this will be the corresponding train_8 for validation /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/specific_data --dataset ICFHR --cuda --lr 0.0001 
#--displayInterval 120 --valEpoch 1 --saveEpoch 1 --workers 10 --niter 15 --experiment this should be a name unique to the train setexperiments/expr_ICFHR_17Apr_binarization_augmentation 
#--keep_ratio --imgH 60 --imgW 240 --batchSize 6 --binarize > name unique to the train set log_files/log_ICFHR_17Apr_binarization_augmentation.txt

#python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR/general_data 
#--valroot /deep_data/nephi/data/lmdb_ICFHR/test_data/30865_testtrack 
#--crnn /deep_data/nephi/experiments/expr_ICFHR_27Mar_alph_werr_fixed_extended/netCRNN_20_5963.pth 
#--cuda --lr 0.00005 --displayInterval 120 --valEpoch 5 --saveEpoch 10 --workers 10 --niter 200
#--experiment experiments/expr_ICFHR_24Mar_testset_test --keep_ratio --imgH 80 --imgW 240 --batchSize 32
#--test_icfhr --test_file 30865_0_unicodeformatted.txt > log_ICFHR_27Mar_russell_testset_test.txt
i = 0
for num in set([d.partition("_train_")[0] for d in dirs]):
    for s in ["0", "1", "4", "16"]:
        script = ''
        if s == "0":
            script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num), 
                           "--valroot", os.path.join(lmdb_database_base, num), 
                           "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15",
                           "--keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize", "--test_aug --n_aug 20" ,
                           #"--experiment", "experiments/expr_" + "ICFHR_18Apr_finetuning_allnet_" + num + "_train_" + s, 
                           "--crnn",  "experiments/expr_ICFHR_27Apr_binarization_distortion_randomaffine_testside/netCRNN_27_5963.pth", 
                           "--test_icfhr --test_file", os.path.join("test_results/28Apr_second_submission_fullaugment_", num + "_" + s + ".txt"), ">",
                           "log_files/test_logs/log_ICFHR_28Apr_test_results_second_submission_fullaugment_" + num + "_" + s + ".txt"])
        else:
            script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num), 
                           "--valroot", os.path.join(lmdb_database_base, num), 
                           "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15",
                           "--keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize", "--test_aug --n_aug 20" ,
                           #"--experiment", "experiments/expr_" + "ICFHR_18Apr_finetuning_allnet_" + num + "_train_" + s, 
                           "--crnn",  tuned_models[i], 
                           "--test_icfhr --test_file", os.path.join("test_results/28Apr_second_submission_fullaugment_", num + "_" + s + ".txt"), ">",
                           "log_files/test_logs/log_ICFHR_28Apr_test_results_second_submission_fullaugment_" + num + "_" + s + ".txt"])
            i = i + 1
        print(script)
        print()

# %% [markdown]
# ## THese were the test set predictions for the second submission. They did poorly with 0 and 1 specific training pages because I trained the general data on smaller images and never tuned up to larger images.

# %%
#experiments/expr_ICFHR_17Apr_binarization_augmentation/netCRNN_6_1988.pth
lmdb_database_base = "/deep_data/nephi/data/lmdb_ICFHR_bin/test_data_each_doc/"

tuned_models = ["/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35013_train_1/netCRNN_28_19.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35013_train_4/netCRNN_38_78.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35013_train_16/netCRNN_27_321.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30882_train_1/netCRNN_38_11.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30882_train_4/netCRNN_28_42.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30882_train_16/netCRNN_32_164.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30893_train_1/netCRNN_4_10.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30893_train_4/netCRNN_32_44.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30893_train_16/netCRNN_36_192.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30866_train_1/netCRNN_24_15.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30866_train_4/netCRNN_37_58.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_30866_train_16/netCRNN_38_235.pth",
                
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35015_train_1/netCRNN_30_34.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35015_train_4/netCRNN_38_132.pth",
                "/home/remi10001/deep_data/experiments/expr_ICFHR_28Apr_finetuning_fullaugment_35015_train_16/netCRNN_28_529.pth"]

# Let's make the script
#python crnn_main.py --trainroot this is the specific data 1, 4, 16 /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/general_data 
#--valroot this will be the corresponding train_8 for validation /home/ubuntu/russell/nephi/data/lmdb_ICFHR_bin/specific_data --dataset ICFHR --cuda --lr 0.0001 
#--displayInterval 120 --valEpoch 1 --saveEpoch 1 --workers 10 --niter 15 --experiment this should be a name unique to the train setexperiments/expr_ICFHR_17Apr_binarization_augmentation 
#--keep_ratio --imgH 60 --imgW 240 --batchSize 6 --binarize > name unique to the train set log_files/log_ICFHR_17Apr_binarization_augmentation.txt

#python crnn_main.py --trainroot /deep_data/nephi/data/lmdb_ICFHR/general_data 
#--valroot /deep_data/nephi/data/lmdb_ICFHR/test_data/30865_testtrack 
#--crnn /deep_data/nephi/experiments/expr_ICFHR_27Mar_alph_werr_fixed_extended/netCRNN_20_5963.pth 
#--cuda --lr 0.00005 --displayInterval 120 --valEpoch 5 --saveEpoch 10 --workers 10 --niter 200
#--experiment experiments/expr_ICFHR_24Mar_testset_test --keep_ratio --imgH 80 --imgW 240 --batchSize 32
#--test_icfhr --test_file 30865_0_unicodeformatted.txt > log_ICFHR_27Mar_russell_testset_test.txt
i = 0
for num in set([d.partition("_train_")[0] for d in dirs]):
    for s in ["0", "1", "4", "16"]:
        script = ''
        if s == "0":
            script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num), 
                           "--valroot", os.path.join(lmdb_database_base, num), 
                           "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15",
                           "--keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize", "--test_aug --n_aug 20" ,
                           #"--experiment", "experiments/expr_" + "ICFHR_18Apr_finetuning_allnet_" + num + "_train_" + s, 
                           "--crnn",  "experiments/expr_ICFHR_27Apr_binarization_distortion_randomaffine_testside/netCRNN_27_5963.pth", 
                           "--test_icfhr --test_file", os.path.join("test_results/28Apr_second_submission_fullaugment", num + "_" + s + ".txt"), ">",
                           "log_files/test_logs/log_ICFHR_28Apr_test_results_second_submission_fullaugment_" + num + "_" + s + ".txt"])
        else:
            script = ' '.join(["python crnn_main.py", "--trainroot", os.path.join(lmdb_database_base, num), 
                           "--valroot", os.path.join(lmdb_database_base, num), 
                           "--dataset ICFHR --cuda --lr 0.0001 --displayInterval 4 --valEpoch 1 --saveEpoch 1 --workers 3 --niter 15",
                           "--keep_ratio --imgH 60 --imgW 240 --batchSize 2 --binarize", "--test_aug --n_aug 20" ,
                           #"--experiment", "experiments/expr_" + "ICFHR_18Apr_finetuning_allnet_" + num + "_train_" + s, 
                           "--crnn",  tuned_models[i], 
                           "--test_icfhr --test_file", os.path.join("test_results/28Apr_second_submission_fullaugment", num + "_" + s + ".txt"), ">",
                           "log_files/test_logs/log_ICFHR_28Apr_test_results_second_submission_fullaugment_" + num + "_" + s + ".txt"])
            i = i + 1
        print(script)
        print

# %% [markdown]
# # Below is code I wrote in developing this notebook

# %%
/deep_data/datasets/ICFHR_Data/specific_data_train_list
/deep_data/datasets/ICFHR_Data/specific_data_val_list

num = str(30882)

spec_data = "/deep_data/datasets/ICFHR_Data/specific_data"
spec_tr_lists_dir = "/deep_data/datasets/ICFHR_Data/specific_data_train_list"
spec_lists_files = glob(os.path.join(spec_tr_lists_dir, "*"))

total_files = glob(os.path.join(spec_data, num + "_train", "*/*.jpg"))
base_files = set([os.path.basename(f) for f in total_files])

list_1 = "/deep_data/datasets/ICFHR_Data/specific_data_train_list/30882_train_1.lst"
list_4 = "/deep_data/datasets/ICFHR_Data/specific_data_train_list/30882_train_4.lst"
list_16 = "/deep_data/datasets/ICFHR_Data/specific_data_train_list/30882_train_16.lst"

fs_1 = set(open(list_1).read().split())
fs_4 = set(open(list_4).read().split())
fs_16 = set(open(list_16).read().split())
fs_8 = fs_16 - fs_4

# %% [markdown]
# ## I was trying to figure a python way of running loop through the shell but I might as well just print all the shell commands and run the script itself. That won't be hard at all. (running script to make all of these lmdb databases. But now my time is up.
#
# # Next step is to make the 8 lists and then just create the script. Not hard at all

# %%
! ls $lmdb_database_base
# Out:
# 30866_train_1	30882_train_1	30893_train_1	35013_train_1	35015_train_1
# 30866_train_16	30882_train_16	30893_train_16	35013_train_16	35015_train_16
# 30866_train_4	30882_train_4	30893_train_4	35013_train_4	35015_train_4
# 30866_train_8	30882_train_8	30893_train_8	35013_train_8	35015_train_8

# %%
spec_data = "/home/ubuntu/datasets/read_ICFHR/specific_data"
spec_tr_lists_dir = "/home/ubuntu/datasets/read_ICFHR/specific_data_train_list"
spec_lists_files = glob(os.path.join(spec_tr_lists_dir, "*"))

# %%
spec_lists_files
# Out:
# ['/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30866_train_1.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_4.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_1.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/35013_train_4.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/35015_train_16.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30866_train_16.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30893_train_16.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_16.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/35015_train_1.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30893_train_4.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/35013_train_1.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/35015_train_4.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30866_train_4.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30893_train_1.lst',
#  '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/35013_train_16.lst']

# %%
for f in spec_lists_files:
    if "30882" in f:
        print(f)
# Out:
# /home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_4.lst
# /home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_1.lst
# /home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_16.lst

# %%
with open(spec_lists_files[1], "r") as f:
    
    print(f.read())

# %%
    
    folderPath = os.path.join('folder_name', os.path.basename(filePath))
shutil.copyfile(filePath, folderPath)
# Out:
# 30882_0004_1065839_region_1439904809242_204_line_1439904834897_206.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904843793_207.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904853185_208.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904869649_209.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904881136_210.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904890756_211.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904904562_212.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904914236_213.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904927283_214.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904941685_215.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904955219_216.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904965800_217.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904980099_218.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904991252_219.jpg
# 30882_0004_1065839_region_1439904809242_204_line_1439904997120_220.jpg
# 30882_0004_1065839_region_1439904814953_205_line_1439905012257_221.jpg
# 30882_0004_1065839_region_1439904814953_205_line_1439905021950_222.jpg
# 30882_0004_1065839_region_1439904814953_205_line_1439905030978_223.jpg
# 30882_0004_1065839_region_1439904814953_205_line_1439905042317_224.jpg
# 30882_0004_1065839_region_1439904814953_205_line_1439905050739_225.jpg
# 30882_0004_1065839_region_1439904814953_205_line_1439905059558_226.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905187367_235.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905197406_236.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905207691_237.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905221082_238.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905231902_239.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905243129_240.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905253367_241.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905266483_242.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905275154_243.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905285409_244.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905293800_245.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905302922_246.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905312008_247.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905320964_248.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905096146_228.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905105822_229.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905118154_230.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905129236_231.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905139331_232.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905150315_233.jpg
# 30882_0005_1065848_region_1439905076838_227_line_1439905177194_234.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055403135_54.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055543553_55.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055552573_56.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055561143_57.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055571240_58.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055582158_59.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055597103_60.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055610098_61.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055621965_62.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055633160_63.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055643466_64.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055653990_65.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055663525_66.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055672291_67.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055687942_68.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055699362_69.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055709822_70.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055717529_71.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055729141_72.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055740954_73.jpg
# 30882_0006_1065855_region_1440055363687_52_line_1440055749516_74.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440055810171_76.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440055823899_77.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440055835707_78.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056039968_79.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056054235_80.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056067470_81.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056079082_82.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056091254_83.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056105239_84.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056117318_85.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056317770_86.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056324482_87.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056336411_88.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056345850_89.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056360825_90.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056374068_91.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056385004_92.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056393441_93.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056403426_94.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056414202_95.jpg
# 30882_0007_1065865_region_1440055788947_75_line_1440056426134_96.jpg

# %%
with open(spec_lists_files[1], "r") as f:
    
    print(f.read().split())
# Out:
# ['30882_0004_1065839_region_1439904809242_204_line_1439904834897_206.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904843793_207.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904853185_208.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904869649_209.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904881136_210.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904890756_211.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904904562_212.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904914236_213.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904927283_214.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904941685_215.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904955219_216.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904965800_217.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904980099_218.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904991252_219.jpg', '30882_0004_1065839_region_1439904809242_204_line_1439904997120_220.jpg', '30882_0004_1065839_region_1439904814953_205_line_1439905012257_221.jpg', '30882_0004_1065839_region_1439904814953_205_line_1439905021950_222.jpg', '30882_0004_1065839_region_1439904814953_205_line_1439905030978_223.jpg', '30882_0004_1065839_region_1439904814953_205_line_1439905042317_224.jpg', '30882_0004_1065839_region_1439904814953_205_line_1439905050739_225.jpg', '30882_0004_1065839_region_1439904814953_205_line_1439905059558_226.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905187367_235.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905197406_236.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905207691_237.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905221082_238.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905231902_239.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905243129_240.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905253367_241.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905266483_242.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905275154_243.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905285409_244.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905293800_245.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905302922_246.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905312008_247.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905320964_248.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905096146_228.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905105822_229.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905118154_230.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905129236_231.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905139331_232.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905150315_233.jpg', '30882_0005_1065848_region_1439905076838_227_line_1439905177194_234.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055403135_54.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055543553_55.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055552573_56.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055561143_57.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055571240_58.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055582158_59.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055597103_60.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055610098_61.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055621965_62.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055633160_63.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055643466_64.jpg', '30882_0006_1065855_region_1440055363687_52_line_1440055653990_65.jpg', '30882_0006_1065855_region_ ...

# %% [markdown]
# I should do subset analyses of the specific training files with each other and all the files that are present in the full set to try to make a develpment set

# %%
num = str(30882)

spec_data = "/home/ubuntu/datasets/read_ICFHR/specific_data"
spec_tr_lists_dir = "/home/ubuntu/datasets/read_ICFHR/specific_data_train_list"
spec_lists_files = glob(os.path.join(spec_tr_lists_dir, "*"))

total_files = glob(os.path.join(spec_data, num + "_train", "*/*.jpg"))
base_files = set([os.path.basename(f) for f in total_files])

list_1 = "/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_1.lst"
list_4 = "/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_4.lst"
list_16 = "/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_16.lst"

fs_1 = set(open(list_1).read().split())
fs_4 = set(open(list_4).read().split())
fs_16 = set(open(list_16).read().split())
fs_8 = fs_16 - fs_4
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-72cb0f7455e7> in <module>()
#      12 list_16 = "/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_16.lst"
#      13
# ---> 14 fs_1 = set(open(list_1).read().split())
#      15 fs_4 = set(open(list_4).read().split())
#      16 fs_16 = set(open(list_16).read().split())
#
# IOError: [Errno 2] No such file or directory: '/home/ubuntu/datasets/read_ICFHR/specific_data_train_list/30882_train_1.lst'

# %% [markdown]
# Here are the paths for working at my home computer

# %%
num = str(30882)

spec_data = "/deep_data/datasets/ICFHR_Data/specific_data"
spec_tr_lists_dir = "/deep_data/datasets/ICFHR_Data/specific_data_train_list"
spec_lists_files = glob(os.path.join(spec_tr_lists_dir, "*"))

total_files = glob(os.path.join(spec_data, num + "_train", "*/*.jpg"))
base_files = set([os.path.basename(f) for f in total_files])

list_1 = "/deep_data/datasets/ICFHR_Data/specific_data_train_list/30882_train_1.lst"
list_4 = "/deep_data/datasets/ICFHR_Data/specific_data_train_list/30882_train_4.lst"
list_16 = "/deep_data/datasets/ICFHR_Data/specific_data_train_list/30882_train_16.lst"

fs_1 = set(open(list_1).read().split())
fs_4 = set(open(list_4).read().split())
fs_16 = set(open(list_16).read().split())
fs_8 = fs_16 - fs_4

# %% [markdown]
# The code below demonstrates that fs_16 is the same as the total number of files available, and each set of increasing number of pages is a strict subset of the greater page list. (I've shown it for collection 30882, but I am sure it is true for all)
#
# ### Therefore, I think a good validation split for the tuning of training files is to select those files not in fs_4, train on those, then predict on fs_4. Then we should use this model for tuning with 1, 4 and 16 additional pages, as it should be the best model.
# ### I will need to make a split for this "fs_12" and a split for all 1, 4, and 16 subsets for all the document types. Then we can experiment with fine tuning after I enable fine-tuning of convolutional layers.
#
# # I think once I've done this splitting and made lmdb databases of the same, then I can start figuring out how to do a results file from them.

# %%
# Union of all the training files
train_subs = fs_16#fs_1 | fs_4 | fs_16

# What remains of total from this union
diff = base_files - train_subs

# Is fs_1 a strict subset of fs_4?
print(len(fs_1 - fs_4))
# Yes
# Out:
# 0

# %%
len(fs_4)
# Out:
# 84

# %%
len(base_files)
# Out:
# 328

# %%
len(fs_8)
# Out:
# 244
